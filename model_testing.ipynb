# %%
from tensorflow.keras.models import load_model

# %%
import numpy as np

# %%
data=np.load('testing_data_.npz')

# %%
x=data['x_test']
y=data['y_test']
del data

# %%
print(x.shape)
from PIL import Image
img=Image.fromarray(np.reshape(x[0][0]*255,(64,64)))
img.show()
# Out:
# (20100, 2, 64, 64)

# %%
x=np.reshape(x,(20100,64, 64,2,1))

# %%
model=load_model('model.h5')

# %%
model.evaluate(x,y)
# Out:
# 20100/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...
